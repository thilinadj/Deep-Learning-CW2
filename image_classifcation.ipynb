# %%
# !pip install -q datasets transformers

# %%
from datasets import load_dataset 

dataset = load_dataset("fashion_mnist")
# Out:
# Downloading builder script:   0%|          | 0.00/4.83k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.13k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.82k [00:00<?, ?B/s]
# Downloading and preparing dataset fashion_mnist/fashion_mnist to /root/.cache/huggingface/datasets/fashion_mnist/fashion_mnist/1.0.0/8d6c32399aa01613d96e2cbc9b13638f359ef62bb33612b077b4c247f6ef99c1...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/26.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/29.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.42M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.15k [00:00<?, ?B/s]
# Extracting data files #1:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #2:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #0:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #3:   0%|          | 0/1 [00:00<?, ?obj/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset fashion_mnist downloaded and prepared to /root/.cache/huggingface/datasets/fashion_mnist/fashion_mnist/1.0.0/8d6c32399aa01613d96e2cbc9b13638f359ef62bb33612b077b4c247f6ef99c1. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from datasets import load_metric

metric = load_metric("accuracy")
# Out:
# <ipython-input-6-350fcae91df9>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
example=dataset["train"][0]

# %%
dataset["train"].features
# Out:
# {'image': Image(decode=True, id=None),
#  'label': ClassLabel(names=['T - shirt / top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'], id=None)}

# %%
example['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28 at 0x7FE69455F580>

# %%
example['image'].resize((200, 200))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7FE694839160>

# %%
example['label']
# Out:
# 9

# %%
dataset["train"].features["label"]
# Out:
# ClassLabel(names=['T - shirt / top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'], id=None)

# %%
labels = dataset["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

id2label[2]
# Out:
# 'Pullover'

# %%
from transformers import AutoFeatureExtractor

feature_extractor = AutoFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")
feature_extractor
# Out:
# Downloading:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/502 [00:00<?, ?B/s]
# ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "size": 224
# }

# %%
from torchvision.transforms import RandomResizedCrop, Compose, Normalize, ToTensor

normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
_transforms = Compose([RandomResizedCrop(feature_extractor.size), ToTensor(), normalize])

# %%
def transforms(examples):
    examples["pixel_values"] = [_transforms(img.convert("RGB")) for img in examples["image"]]
    del examples["image"]
    return examples

# %%
dataset = dataset.with_transform(transforms)

# %%
dataset['train'][0]
# Out:
# {'label': 9,
#  'pixel_values': tensor([[[-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           ...,
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           ...,
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.7333,  0.7333,  0.7333],
#           ...,
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000]]])}

# %%
from transformers import DefaultDataCollator

data_collator = DefaultDataCollator()

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model = AutoModelForImageClassification.from_pretrained(
    "google/vit-base-patch16-224-in21k",
    num_labels=len(labels),
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes = True,
)
# Out:
# Downloading:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_checkpoint='google/vit-base-patch16-224-in21k'
batch_size = 32

# %%
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=16,
    evaluation_strategy="steps",
    num_train_epochs=4,
    fp16=True,
    save_steps=100,
    eval_steps=100,
    logging_steps=10,
    learning_rate=2e-4,
    save_total_limit=2,
    remove_unused_columns=False,
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=feature_extractor,
)

trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Using cuda_amp half precision backend
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 60000
#   Num Epochs = 4
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 15000
#   Number of trainable parameters = 85806346
#     <div>
#
#       <progress value='7529' max='15000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7529/15000 1:43:15 < 1:42:29, 1.21 it/s, Epoch 2.01/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.512400</td>
#       <td>0.654455</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.341600</td>
#       <td>0.647906</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.529800</td>
#       <td>0.601065</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.503100</td>
#       <td>0.608353</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.449400</td>
#       <td>0.598983</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.334500</td>
#       <td>0.571863</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.576100</td>
#       <td>0.629804</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.521100</td>
#       <td>0.539424</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.578400</td>
#       <td>0.694452</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.502000</td>
#       <td>0.542580</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.407700</td>
#       <td>0.548778</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.426500</td>
#       <td>0.530509</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.535900</td>
#       <td>0.611741</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.486100</td>
#       <td>0.559669</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.410100</td>
#       <td>0.561367</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.385400</td>
#       <td>0.546695</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.381200</td>
#       <td>0.534868</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.606900</td>
#       <td>0.553608</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.607400</td>
#       <td>0.515991</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.361700</td>
#       <td>0.527346</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.451500</td>
#       <td>0.512720</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.429900</td>
#       <td>0.514048</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.615900</td>
#       <td>0.590657</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.594000</td>
#       <td>0.544625</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.429800</td>
#       <td>0.488161</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.594500</td>
#       <td>0.501943</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.445600</td>
#       <td>0.515868</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.607400</td>
#       <td>0.514052</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.502900</td>
#       <td>0.483574</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.505400</td>
#       <td>0.483512</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.535400</td>
#       <td>0.483512</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.448700</td>
#       <td>0.504618</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.378400</td>
#       <td>0.496009</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.482500</td>
#       <td>0.502174</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.422000</td>
#       <td>0.487653</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.544500</td>
#       <td>0.521740</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.464100</td>
#       <td>0.495671</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.443800</td>
#       <td>0.451323</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.395400</td>
#       <td>0.486534</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.366100</td>
#       <td>0.485294</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.391800</td>
#       <td>0.475902</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.434800</td>
#       <td>0.602746</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.468700</td>
#       <td>0.498488</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.544100</td>
#       <td>0.441507</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.378600</td>
#       <td>0.432252</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.422800</td>
#       <td>0.433906</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.471900</td>
#       <td>0.466173</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.371200</td>
#       <td>0.450323</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.439000</td>
#       <td>0.475632</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.376900</td>
#       <td>0.464966</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.428100</td>
#       <td>0.437625</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.459100</td>
#       <td>0.452022</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.381900</td>
#       <td>0.420551</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.384500</td>
#       <td>0.459859</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.385300</td>
#       <td>0.447569</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.270700</td>
#       <td>0.443281</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.351900</td>
#       <td>0.465463</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.406700</td>
#       <td>0.427306</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.370200</td>
#       <td>0.468650</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.452900</td>
#       <td>0.421844</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.260000</td>
#       <td>0.409552</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.496600</td>
#       <td>0.413971</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.398900</td>
#       <td>0.421764</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.384900</td>
#       <td>0.457522</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.396000</td>
#       <td>0.429951</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.365000</td>
#       <td>0.445914</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.387800</td>
#       <td>0.447416</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.318200</td>
#       <td>0.425568</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.250300</td>
#       <td>0.420985</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.313900</td>
#       <td>0.419007</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.574600</td>
#       <td>0.478677</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.446400</td>
#       <td>0.429157</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.345500</td>
#       <td>0.410743</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.373900</td>
#       <td>0.402219</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.350300</td>
#       <td>0.404957</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-100
# Configuration saved in ./results/checkpoint-100/config.json
# Model weights saved in ./results/checkpoint-100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-200
# Configuration saved in ./results/checkpoint-200/config.json
# Model weights saved in ./results/checkpoint-200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-300
# Configuration saved in ./results/checkpoint-300/config.json
# Model weights saved in ./results/checkpoint-300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-400
# Configuration saved in ./results/checkpoint-400/config.json
# Model weights saved in ./results/checkpoint-400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-500
# Configuration saved in ./results/checkpoint-500/config.json
# Model weights saved in ./results/checkpoint-500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-600
# Configuration saved in ./results/checkpoint-600/config.json
# Model weights saved in ./results/checkpoint-600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-700
# Configuration saved in ./results/checkpoint-700/config.json
# Model weights saved in ./results/checkpoint-700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-800
# Configuration saved in ./results/checkpoint-800/config.json
# Model weights saved in ./results/checkpoint-800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-900
# Configuration saved in ./results/checkpoint-900/config.json
# Model weights saved in ./results/checkpoint-900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1000
# Configuration saved in ./results/checkpoint-1000/config.json
# Model weights saved in ./results/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1100
# Configuration saved in ./results/checkpoint-1100/config.json
# Model weights saved in ./results/checkpoint-1100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1200
# Configuration saved in ./results/checkpoint-1200/config.json
# Model weights saved in ./results/checkpoint-1200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1300
# Configuration saved in ./results/checkpoint-1300/config.json
# Model weights saved in ./results/checkpoint-1300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1400
# Configuration saved in ./results/checkpoint-1400/config.json
# Model weights saved in ./results/checkpoint-1400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1500
# Configuration saved in ./results/checkpoint-1500/config.json
# Model weights saved in ./results/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1600
# Configuration saved in ./results/checkpoint-1600/config.json
# Model weights saved in ./results/checkpoint-1600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1700
# Configuration saved in ./results/checkpoint-1700/config.json
# Model weights saved in ./results/checkpoint-1700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1800
# Configuration saved in ./results/checkpoint-1800/config.json
# Model weights saved in ./results/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1900
# Configuration saved in ./results/checkpoint-1900/config.json
# Model weights saved in ./results/checkpoint-1900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-1900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2000
# Configuration saved in ./results/checkpoint-2000/config.json
# Model weights saved in ./results/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2100
# Configuration saved in ./results/checkpoint-2100/config.json
# Model weights saved in ./results/checkpoint-2100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-1900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2200
# Configuration saved in ./results/checkpoint-2200/config.json
# Model weights saved in ./results/checkpoint-2200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2300
# Configuration saved in ./results/checkpoint-2300/config.json
# Model weights saved in ./results/checkpoint-2300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2400
# Configuration saved in ./results/checkpoint-2400/config.json
# Model weights saved in ./results/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2500
# Configuration saved in ./results/checkpoint-2500/config.json
# Model weights saved in ./results/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2600
# Configuration saved in ./results/checkpoint-2600/config.json
# Model weights saved in ./results/checkpoint-2600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2700
# Configuration saved in ./results/checkpoint-2700/config.json
# Model weights saved in ./results/checkpoint-2700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2800
# Configuration saved in ./results/checkpoint-2800/config.json
# Model weights saved in ./results/checkpoint-2800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2900
# Configuration saved in ./results/checkpoint-2900/config.json
# Model weights saved in ./results/checkpoint-2900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-2900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3000
# Configuration saved in ./results/checkpoint-3000/config.json
# Model weights saved in ./results/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3100
# Configuration saved in ./results/checkpoint-3100/config.json
# Model weights saved in ./results/checkpoint-3100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-2900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3200
# Configuration saved in ./results/checkpoint-3200/config.json
# Model weights saved in ./results/checkpoint-3200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3300
# Configuration saved in ./results/checkpoint-3300/config.json
# Model weights saved in ./results/checkpoint-3300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3400
# Configuration saved in ./results/checkpoint-3400/config.json
# Model weights saved in ./results/checkpoint-3400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3500
# Configuration saved in ./results/checkpoint-3500/config.json
# Model weights saved in ./results/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3600
# Configuration saved in ./results/checkpoint-3600/config.json
# Model weights saved in ./results/checkpoint-3600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3700
# Configuration saved in ./results/checkpoint-3700/config.json
# Model weights saved in ./results/checkpoint-3700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3800
# Configuration saved in ./results/checkpoint-3800/config.json
# Model weights saved in ./results/checkpoint-3800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-3900
# Configuration saved in ./results/checkpoint-3900/config.json
# Model weights saved in ./results/checkpoint-3900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-3900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4000
# Configuration saved in ./results/checkpoint-4000/config.json
# Model weights saved in ./results/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4100
# Configuration saved in ./results/checkpoint-4100/config.json
# Model weights saved in ./results/checkpoint-4100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-3900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4200
# Configuration saved in ./results/checkpoint-4200/config.json
# Model weights saved in ./results/checkpoint-4200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4300
# Configuration saved in ./results/checkpoint-4300/config.json
# Model weights saved in ./results/checkpoint-4300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4400
# Configuration saved in ./results/checkpoint-4400/config.json
# Model weights saved in ./results/checkpoint-4400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4500
# Configuration saved in ./results/checkpoint-4500/config.json
# Model weights saved in ./results/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4600
# Configuration saved in ./results/checkpoint-4600/config.json
# Model weights saved in ./results/checkpoint-4600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4700
# Configuration saved in ./results/checkpoint-4700/config.json
# Model weights saved in ./results/checkpoint-4700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4800
# Configuration saved in ./results/checkpoint-4800/config.json
# Model weights saved in ./results/checkpoint-4800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-4900
# Configuration saved in ./results/checkpoint-4900/config.json
# Model weights saved in ./results/checkpoint-4900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-4900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5000
# Configuration saved in ./results/checkpoint-5000/config.json
# Model weights saved in ./results/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5100
# Configuration saved in ./results/checkpoint-5100/config.json
# Model weights saved in ./results/checkpoint-5100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-4900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5200
# Configuration saved in ./results/checkpoint-5200/config.json
# Model weights saved in ./results/checkpoint-5200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5300
# Configuration saved in ./results/checkpoint-5300/config.json
# Model weights saved in ./results/checkpoint-5300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5400
# Configuration saved in ./results/checkpoint-5400/config.json
# Model weights saved in ./results/checkpoint-5400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5500
# Configuration saved in ./results/checkpoint-5500/config.json
# Model weights saved in ./results/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5600
# Configuration saved in ./results/checkpoint-5600/config.json
# Model weights saved in ./results/checkpoint-5600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5700
# Configuration saved in ./results/checkpoint-5700/config.json
# Model weights saved in ./results/checkpoint-5700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5800
# Configuration saved in ./results/checkpoint-5800/config.json
# Model weights saved in ./results/checkpoint-5800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-5900
# Configuration saved in ./results/checkpoint-5900/config.json
# Model weights saved in ./results/checkpoint-5900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-5900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6000
# Configuration saved in ./results/checkpoint-6000/config.json
# Model weights saved in ./results/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6100
# Configuration saved in ./results/checkpoint-6100/config.json
# Model weights saved in ./results/checkpoint-6100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-5900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6200
# Configuration saved in ./results/checkpoint-6200/config.json
# Model weights saved in ./results/checkpoint-6200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6300
# Configuration saved in ./results/checkpoint-6300/config.json
# Model weights saved in ./results/checkpoint-6300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6400
# Configuration saved in ./results/checkpoint-6400/config.json
# Model weights saved in ./results/checkpoint-6400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6500
# Configuration saved in ./results/checkpoint-6500/config.json
# Model weights saved in ./results/checkpoint-6500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6600
# Configuration saved in ./results/checkpoint-6600/config.json
# Model weights saved in ./results/checkpoint-6600/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6600/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6700
# Configuration saved in ./results/checkpoint-6700/config.json
# Model weights saved in ./results/checkpoint-6700/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6700/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6800
# Configuration saved in ./results/checkpoint-6800/config.json
# Model weights saved in ./results/checkpoint-6800/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6800/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-6900
# Configuration saved in ./results/checkpoint-6900/config.json
# Model weights saved in ./results/checkpoint-6900/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-6900/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7000
# Configuration saved in ./results/checkpoint-7000/config.json
# Model weights saved in ./results/checkpoint-7000/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7000/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7100
# Configuration saved in ./results/checkpoint-7100/config.json
# Model weights saved in ./results/checkpoint-7100/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7100/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-6900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7200
# Configuration saved in ./results/checkpoint-7200/config.json
# Model weights saved in ./results/checkpoint-7200/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7200/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-7000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7300
# Configuration saved in ./results/checkpoint-7300/config.json
# Model weights saved in ./results/checkpoint-7300/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7300/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-7100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7400
# Configuration saved in ./results/checkpoint-7400/config.json
# Model weights saved in ./results/checkpoint-7400/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7400/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-7200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-7500
# Configuration saved in ./results/checkpoint-7500/config.json
# Model weights saved in ./results/checkpoint-7500/pytorch_model.bin
# Feature extractor saved in ./results/checkpoint-7500/preprocessor_config.json
# Deleting older checkpoint [results/checkpoint-7300] due to args.save_total_limit

# %%
metrics = trainer.evaluate()
# some nice to haves:
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
