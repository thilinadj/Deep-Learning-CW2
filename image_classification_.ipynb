# %% [markdown]
# <a href="https://colab.research.google.com/github/thilinadj/Deep-Learning-CW2/blob/kirthika/image_classification_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q datasets transformers
# Out:
#      |████████████████████████████████| 451 kB 14.5 MB/s
#      |████████████████████████████████| 5.8 MB 71.2 MB/s
#      |████████████████████████████████| 132 kB 75.8 MB/s
#      |████████████████████████████████| 182 kB 79.9 MB/s
#      |████████████████████████████████| 212 kB 72.0 MB/s
#      |████████████████████████████████| 127 kB 70.5 MB/s
#      |████████████████████████████████| 7.6 MB 45.0 MB/s

# %%
import torch
from datasets import load_dataset 
from datasets import load_metric
from transformers import AutoFeatureExtractor
from torchvision.transforms import RandomResizedCrop, Compose, Normalize, ToTensor
from transformers import DefaultDataCollator
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

# %%
dataset = load_dataset("fashion_mnist")
# Out:
# Downloading builder script:   0%|          | 0.00/4.83k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.13k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.82k [00:00<?, ?B/s]
# Downloading and preparing dataset fashion_mnist/fashion_mnist to /root/.cache/huggingface/datasets/fashion_mnist/fashion_mnist/1.0.0/8d6c32399aa01613d96e2cbc9b13638f359ef62bb33612b077b4c247f6ef99c1...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/26.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/29.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.42M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.15k [00:00<?, ?B/s]
# Extracting data files #1:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #2:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #3:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #0:   0%|          | 0/1 [00:00<?, ?obj/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset fashion_mnist downloaded and prepared to /root/.cache/huggingface/datasets/fashion_mnist/fashion_mnist/1.0.0/8d6c32399aa01613d96e2cbc9b13638f359ef62bb33612b077b4c247f6ef99c1. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
metric = load_metric("accuracy")
# Out:
# <ipython-input-5-21f3ecd7ee32>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
example=dataset["train"][1]

# %%
dataset["train"].features
# Out:
# {'image': Image(decode=True, id=None),
#  'label': ClassLabel(names=['T - shirt / top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'], id=None)}

# %%
example['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28 at 0x7F609D3AAF40>

# %%
example['image'].resize((200, 200))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F609CA60280>

# %%
example['label']
# Out:
# 0

# %%
dataset["train"].features["label"]
# Out:
# ClassLabel(names=['T - shirt / top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'], id=None)

# %%
labels = dataset["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

id2label[2]
# Out:
# 'Pullover'

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")
feature_extractor
# Out:
# Downloading:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/502 [00:00<?, ?B/s]
# ViTImageProcessor {
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_processor_type": "ViTImageProcessor",
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 224,
#     "width": 224
#   }
# }

# %%
normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
_transforms = Compose([RandomResizedCrop((224,224)), ToTensor(), normalize])

# %%
def transforms(examples):
    examples["pixel_values"] = [_transforms(img.convert("RGB")) for img in examples["image"]]
    del examples["image"]
    return examples

# %%
dataset = dataset.with_transform(transforms)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'label': 9,
#  'pixel_values': tensor([[[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000],
#           [ 0.5686,  0.5686,  0.5686,  ..., -1.0000, -1.0000, -1.0000]]])}

# %%
data_collator = DefaultDataCollator()

# %%
model = AutoModelForImageClassification.from_pretrained(
    "google/vit-base-patch16-224-in21k",
    num_labels=len(labels),
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes = True,
)
# Out:
# Downloading:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_checkpoint='google/vit-base-patch16-224-in21k'
batch_size = 16

# %%
training_args = TrainingArguments(
    output_dir="./drive/My Drive/hugging_face/results",
    remove_unused_columns=False,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=10,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
)

# %%
import numpy as np

# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics
)

# %%
train_results = trainer.train()
# rest is optional but nice to have
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 60000
#   Num Epochs = 10
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 4
#   Total optimization steps = 9370
#   Number of trainable parameters = 85806346
#     <div>
#
#       <progress value='7961' max='9370' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7961/9370 5:10:15 < 54:55, 0.43 it/s, Epoch 8.49/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.506600</td>
#       <td>0.545015</td>
#       <td>0.831000</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.423000</td>
#       <td>0.389419</td>
#       <td>0.864500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.325200</td>
#       <td>0.358537</td>
#       <td>0.876000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.278300</td>
#       <td>0.329384</td>
#       <td>0.885000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.269400</td>
#       <td>0.316050</td>
#       <td>0.887600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.232300</td>
#       <td>0.296499</td>
#       <td>0.893100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.203500</td>
#       <td>0.289959</td>
#       <td>0.895200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.274000</td>
#       <td>0.293483</td>
#       <td>0.896500</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-937
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-937/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-937/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-937/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-1874
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-1874/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-1874/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-1874/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-2811
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-2811/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-2811/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-2811/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-3748
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-3748/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-3748/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-3748/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-4685
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-4685/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-4685/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-4685/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-5622
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-5622/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-5622/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-5622/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-6559
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-6559/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-6559/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-6559/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-7496
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-7496/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-7496/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-7496/preprocessor_config.json
#     <div>
#
#       <progress value='9370' max='9370' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9370/9370 6:06:34, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.506600</td>
#       <td>0.545015</td>
#       <td>0.831000</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.423000</td>
#       <td>0.389419</td>
#       <td>0.864500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.325200</td>
#       <td>0.358537</td>
#       <td>0.876000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.278300</td>
#       <td>0.329384</td>
#       <td>0.885000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.269400</td>
#       <td>0.316050</td>
#       <td>0.887600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.232300</td>
#       <td>0.296499</td>
#       <td>0.893100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.203500</td>
#       <td>0.289959</td>
#       <td>0.895200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.274000</td>
#       <td>0.293483</td>
#       <td>0.896500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.197700</td>
#       <td>0.274072</td>
#       <td>0.903800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.163400</td>
#       <td>0.273803</td>
#       <td>0.904000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-8433
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-8433/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-8433/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-8433/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
# Saving model checkpoint to ./drive/My Drive/hugging_face/results/checkpoint-9370
# Configuration saved in ./drive/My Drive/hugging_face/results/checkpoint-9370/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/checkpoint-9370/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/checkpoint-9370/preprocessor_config.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./drive/My Drive/hugging_face/results/checkpoint-9370 (score: 0.904).
# Saving model checkpoint to ./drive/My Drive/hugging_face/results
# Configuration saved in ./drive/My Drive/hugging_face/results/config.json
# Model weights saved in ./drive/My Drive/hugging_face/results/pytorch_model.bin
# Image processor saved in ./drive/My Drive/hugging_face/results/preprocessor_config.json
# ***** train metrics *****
#   epoch                    =          10.0
#   total_flos               = 43302818779GF
#   train_loss               =        0.3659
#   train_runtime            =    6:06:43.55
#   train_samples_per_second =        27.268
#   train_steps_per_second   =         0.426

# %%
metrics = trainer.evaluate()
# some nice to haves:
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# ***** Running Evaluation *****
#   Num examples = 10000
#   Batch size = 16
#     <div>
#
#       <progress value='625' max='625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [625/625 02:27]
#     </div>
# ***** eval metrics *****
#   epoch                   =       10.0
#   eval_accuracy           =     0.9018
#   eval_loss               =     0.2826
#   eval_runtime            = 0:02:27.57
#   eval_samples_per_second =     67.761
#   eval_steps_per_second   =      4.235

# %%
from transformers import AutoModelForImageClassification, AutoFeatureExtractor

repo_name = "./drive/My Drive/hugging_face/results"

feature_extractor = AutoFeatureExtractor.from_pretrained(repo_name)
my_model = AutoModelForImageClassification.from_pretrained(repo_name)

# %%
from PIL import Image
import requests

url = 'https://png.vector.me/files/images/1/1/119241/black_t_shirt_clip_art.jpg'
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=425x344 at 0x7F7067187460>

# %%
# prepare image for the model
encoding = feature_extractor(image.convert("RGB"), return_tensors="pt")
print(encoding.pixel_values.shape)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
# forward pass
with torch.no_grad():
  outputs = my_model(**encoding)
  logits = outputs.logits

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", my_model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: T - shirt / top
